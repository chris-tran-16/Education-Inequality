# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.utils import shuffle
# from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier
# from xgboost import XGBClassifier
# from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, precision_score, recall_score

data_dir = 'data/final_data/'

# %% [markdown]
# # On the binary data

# %%
data_r = pd.read_csv(data_dir + 'data_binary.csv')
# data_r = pd.read_csv('data/final_data/data.csv')
print(data_r.shape)
# Out:
# (36295, 442)
# D:\Programs\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# non-important information
data_cols = data_r.columns
cols1 = data_cols[0:20]
cols2 = data_cols[26:29]
cols3 = []
cols3 = data_cols[24:26]
data_cols_r = cols1.append(cols2).append(cols3)

print(data_cols_r)
# Out:
# Index(['SURVYEAR', 'NCESSCH', 'FIPST', 'LEAID', 'SCHNO', 'STID', 'SEASCH',
#        'LEANM', 'SCHNAM', 'PHONE', 'MSTREE', 'MCITY', 'MSTATE', 'MZIP',
#        'MZIP4', 'LSTREE', 'LCITY', 'LSTATE', 'LZIP', 'LZIP4', 'CONUM',
#        'CONAME', 'CDCODE', 'LATCOD', 'LONCOD'],
#       dtype='object')

# %%
data = data_r.drop(data_cols_r, axis=1)

# %%
data
# Out:
#        TYPE  STATUS  UNION  ULOCAL  BIES  RECONSTF    FTE  GSLO  GSHI  \
# 0         1       1      0       0     2         2  31.25     5     6
# 1         1       1      0       0     2         2  43.75     3     4
# 2         1       1      0       1     2         2  23.60     5     8
# 3         1       1      0       1     2         2  35.94     6    12
# 4         1       1      0       2     2         2   7.15    -1     4
# 5         1       1      0       1     2         2  26.30     3     5
# 6         1       1      0       1     2         2  33.17     9    12
# 7         1       1      0       2     2         2  14.70     3     5
# 8         1       1      0       1     2         2  28.40     9    12
# 9         1       1      0       2     2         2  16.52     6     8
# 10        1       1      0       2     2         2  25.01     9    12
# 11        1       1      0       1     2         2  31.04     0     4
# 12        1       1      0       1     2         2  22.32     6     8
# 13        1       1      0       1     2         2  39.66    -1     5
# 14        1       1      0       3     2         2  40.00    -1     4
# 15        1       1      0       3     2         2  33.60     0     5
# 16        1       1      0       4     2         2  49.00     0     4
# 17        1       1      0       4     2         2  27.00     5     8
# 18        1       1      0       4     2         2  18.00     9    12
# 19        1       1      0       0     2         2  26.50     6     8
# 20        1       1      0       0     2         2  43.58     9    12
# 21        1       1      0       0     2         2  21.50     2     3
# 22        1       1      0       0     2         2  15.34     4     5
# 23        1       1      0       0     2         2  26.00     7     8
# 24        1       1      0       0     2         2  62.27     9    12
# 25        1       1      0       0     2         2  24.00     3     4
# 17      94.00        47691.489362    -1
# 18      94.00        47691.489362    -1
# 19     137.92        37601.508121    -1
# 20     137.92        37601.508121    -1
# 21     137.92        37601.508121    -1
# 22     137.92        37601.508121    -1
# 23     183.27        43967.916189    -1
# 24     183.27        43967.916189    -1
# 25     183.27        43967.916189    -1
# 26     183.27        43967.916189    -1
# 27     104.73        41373.054521    -1
# 28     104.73        41373.054521    -1
# 29     104.73        41373.054521    -1
# ...       ...                 ...   ...
# 36265  416.46        49003.505739     1
# 36266  416.46        49003.505739    -1
# 36267  416.46        49003.505739    -1
# 36268   15.30        51960.784314    -1
# 36269   15.30        51960.784314    -1
# 36270   82.92        47720.694645    -1
# 36271   82.92        47720.694645    -1
# 36272   82.92        47720.694645    -1
# 36273   82.92        47720.694645    -1
# 36274  256.56        55285.313377    -1
# 36275  256.56        55285.313377    -1
# 36276  256.56        55285.313377    -1
# 36277   30.32        46174.142480    -1
# 36278   30.32        46174.142480    -1
# 36279   30.32        46174.142480    -1
# 36280  225.50        44368.070953    -1
# 36281  225.50        44368.070953    -1
# 36282  225.50        44368.070953    -1
# 36283  225.50        44368.070953    -1
# 36284  225.50        44368.070953    -1
# 36285  225.50        44368.070953    -1
# 36286  225.50        44368.070953    -1
# 36287  215.53        60464.900478    -1
# 36288  215.53        60464.900478    -1
# 36289  215.53        60464.900478    -1
# 36290   28.85        55667.244367    -1
# 36291   28.85        55667.244367    -1
# 36292  114.49        47130.753778    -1
# 36293  114.49        47130.753778    -1
# 36294  114.49        47130.753778    -1
#
# [36295 rows x 417 columns]

# %%
data.shape
# Out:
# (36295, 417)

# %%
# param_grid = {'max_depth': np.arange(6, 30), 'criterion': ['gini', 'entropy'], 'max_features': np.arange(1,x.shape[1])}
# tree_g = GridSearchCV(tree.DecisionTreeClassifier(), param_grid, cv=10, scoring=scoring_methods, n_jobs=4, refit='f1')
# tree_g.fit(x, y)
# tree_g.best_params_

print(np.any(np.isnan(data['avg_teacher_salary'])))
print(np.all(np.isfinite(data['avg_teacher_salary'])))
# Out:
# False
# True

# %%
data_nolabs = data.drop(['prof'], axis=1)

x = data_nolabs.as_matrix()
y = data['prof'].as_matrix()

var = data_nolabs.columns

# %%
print(x.shape)
print(y.shape)

x, y = shuffle(x, y, random_state=0)

scoring_methods = {'accuracy': 'accuracy', 'f1': 'f1', 'roc_auc': 'roc_auc'}
# scoring_methods = {'accuracy': 'accuracy', 'f1': 'f1_macro'}
# Out:
# (36295, 416)
# (36295,)

# %%
clf_tree = tree.DecisionTreeClassifier(criterion='entropy')
clf_tree.fit(x, y)
tree_scores = cross_validate(clf_tree, x,  y, cv=10, return_train_score=False, 
                             scoring=scoring_methods)
tree_scores
# Out:
# {'fit_time': array([ 5.01515603,  5.51224756,  5.3454442 ,  5.37303758,  5.17479825,
#          4.90145087,  4.80060911,  4.98096085,  5.60002565,  4.91227365]),
#  'score_time': array([ 0.01752257,  0.02051377,  0.01949859,  0.0175128 ,  0.01601171,
#          0.01651192,  0.01551104,  0.0165112 ,  0.01751256,  0.01651239]),
#  'test_accuracy': array([ 0.94380165,  0.9476584 ,  0.9446281 ,  0.94517906,  0.94104683,
#          0.94683196,  0.94628099,  0.94516396,  0.94184123,  0.94128997]),
#  'test_f1': array([ 0.9427288 ,  0.94683828,  0.94355518,  0.94479889,  0.94038997,
#          0.94580174,  0.94542401,  0.94449093,  0.94124199,  0.94028595]),
#  'test_roc_auc': array([ 0.94372267,  0.9476257 ,  0.94454548,  0.94526354,  0.9410736 ,
#          0.94674976,  0.94624423,  0.94518024,  0.94187958,  0.94123702])}

# %%
print("Avg Accuracy:", np.mean(tree_scores['test_accuracy']))
print("Avg F-1 Score:", np.mean(tree_scores['test_f1']))
print("Avg AUC:", np.mean(tree_scores['test_roc_auc']))
# Out:
# Avg Accuracy: 0.944372215602
# Avg F-1 Score: 0.943555576161
# Avg AUC: 0.944352181861

# %%
tb = np.sort(clf_tree.feature_importances_)[::-1]
ta = np.argsort(clf_tree.feature_importances_)[::-1]

var[ta[tb>=.01]]
# Out:
# Index(['child_poverty', 'MAGNET', 'WHALF', 'SHARED', 'C38', 'C08', 'C04',
#        'FRELCH', 'C10', 'ALL_RLA00NUMVALID_1314', 'C35', 'A07', 'LEVEL',
#        'CHARTR', 'C24', 'A13'],
#       dtype='object')

# %% [raw]
# rfe = RFECV(clf_tree, cv=5, n_jobs=4, step=.1)
# rfe = rfe.fit(x, y)
# # summarize the selection of the attributes

# %% [raw]
# print(var[rfe.support_])
# # print(rfe.ranking_)

# %%
clf_tree
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# %%time

clf_rf = RandomForestClassifier(n_estimators=100)
clf_rf.fit(x, y)
rf_scores = cross_validate(clf_rf, x,  y, cv=10, return_train_score=False, 
                          scoring=scoring_methods)
rf_scores
# Out:
# Wall time: 4min 7s

# %%
print("Avg Accuracy:", np.mean(rf_scores['test_accuracy']))
print("Avg F-1 Score:", np.mean(rf_scores['test_f1']))
print("Avg AUC:", np.mean(rf_scores['test_roc_auc']))
# Out:
# Avg Accuracy: 0.970381612735
# Avg F-1 Score: 0.969697641083
# Avg AUC: 0.995174716115

# %%
rfb = np.sort(clf_rf.feature_importances_)[::-1]
rfa = np.argsort(clf_rf.feature_importances_)[::-1]

var[rfa]
# Out:
# Index(['child_poverty', 'MAGNET', 'C38', 'NSLPSTATUS', 'WHITE', 'WHALF', 'C08',
#        'TOTFRL', 'FRELCH', 'A13',
#        ...
#        'G08OFFRD', 'G05OFFRD', 'G04OFFRD', 'G01OFFRD', 'G02OFFRD', 'KGOFFRD',
#        'G03OFFRD', 'V85', 'WEIGHT', 'BIES'],
#       dtype='object', length=416)

# %%
clf_rf # show parameters
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [raw]
# clf_xgboost = XGBClassifier(learning_rate=.2, max_depth=6)
# clf_xgboost.fit(x, y)
# xgscores = cross_validate(clf_xgboost, x,  y, cv=10, return_train_score=False,
#                          scoring=scoring_methods)
# xgscores

# %% [raw]
# print("Avg Accuracy:", np.mean(xgscores['test_accuracy']))
# print("Avg F-1 Score:", np.mean(xgscores['test_f1']))
# print("Avg AUC:", np.mean(xgscores['test_roc_auc']))

# %% [raw]
# xgb = np.sort(clf_xgboost.feature_importances_)[::-1]
# xga = np.argsort(clf_xgboost.feature_importances_)[::-1]
#
# var[xga]

# %% [raw]
# clf_xgboost # show parameters

# %% [markdown]
# # Test set evaulation

# %%
rf_model = RandomForestClassifier(n_estimators=100)
# rf_model = RandomForestClassifier(criterion='entropy', max_features=.25, n_estimators=50, n_jobs=4)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2,stratify=y)

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (29036, 416)
# (29036,)
# (7259, 416)
# (7259,)

# %%
# %time rf_model.fit(x_train, y_train)
# Out:
# CPU times: user 3min 39s, sys: 68 ms, total: 3min 39s
# Wall time: 3min 39s
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = rf_model.predict(x_test)
print("Accuracy on test:", accuracy_score(y_test, y_pred))
print("Precision on test:", precision_score(y_test, y_pred))
print("Recall on test:", recall_score(y_test, y_pred))
print("F-1 on test:", f1_score(y_test, y_pred))
print("AUC on test:", roc_auc_score(y_test, y_pred))
# Out:
# Accuracy on test: 0.968866235019
# Precision on test: 0.975602836879
# Recall on test: 0.960882928192
# F-1 on test: 0.968186936937
# AUC on test: 0.968756681487

# %%
# rf_model.estimators_

# %%
plt.rcParams.update({'font.size': 22})

forest = rf_model

importances = forest.feature_importances_

std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# for f in range(x.shape[1]):
#     print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest

num_features = 20

plt.figure(figsize=(20,10), dpi=100)
plt.title("Feature importances")
plt.bar(range(num_features), importances[indices[:num_features]],
       color="r", yerr=std[indices[:num_features]], align="center")
plt.xticks(range(num_features), var[indices[:num_features]], rotation='vertical')
plt.xlim([-1,num_features])
plt.show()

# importances[indices[:num_features]]
# std[indices[:num_features]]

# range(x.shape[1])

# %%
rfb = np.sort(rf_model.feature_importances_)[::-1]
rfa = np.argsort(rf_model.feature_importances_)[::-1]
var[rfa[rfb>=.005]]
# Out:
# Index(['child_poverty', 'MAGNET', 'C38', 'NSLPSTATUS', 'WHALF', 'WHALM', 'C08',
#        'FRELCH', 'WHITE', 'TOTFRL', 'C12', 'A13', 'C39', 'C13', 'TITLEISTAT',
#        'ASALF', 'C24', 'ASIAN', 'SHARED', 'C05', 'VIRTUALSTAT', 'TITLEI',
#        'STITLI', 'C20', 'T09', 'V92', 'T40', 'Z38', 'T15', 'C06',
#        'avg_teacher_salary', 'V16', 'T99', 'C04', 'ASALM', 'TNONELSE', 'C14',
#        'T06', 'C35', 'C10', 'C16', 'C36', 'U30', 'C09', 'W31', 'CHARTR'],
#       dtype='object')

# %%
rfb[rfb >= .005]
# Out:
# array([ 0.03740851,  0.03061493,  0.02016247,  0.0185336 ,  0.01807135,
#         0.01742168,  0.01702844,  0.0164317 ,  0.01614176,  0.01397861,
#         0.0138107 ,  0.01293636,  0.01283324,  0.01268792,  0.0117282 ,
#         0.01133393,  0.0112906 ,  0.01092985,  0.01067421,  0.0106405 ,
#         0.01024543,  0.00997988,  0.00996096,  0.00952978,  0.00934602,
#         0.00876019,  0.00857276,  0.00851591,  0.00773035,  0.0074809 ,
#         0.00745259,  0.00708494,  0.00706363,  0.0070507 ,  0.0066335 ,
#         0.00654025,  0.00652709,  0.0062485 ,  0.00614856,  0.00579884,
#         0.00557778,  0.00555438,  0.00552462,  0.00530972,  0.00528091,
#         0.00517931])

# %%
np.min(rfb)
# Out:
# 0.0

# %% [raw]
# rf_mod2 = RandomForestClassifier(n_estimators=100)
#
# xt = x_train[:, rfb>=.005]
# xts = x_test[:, rfb>=.005]
# var2 = var[rfa[rfb>=.005]]

# %% [raw]
# %time rf_mod2.fit(xt, y_train)

# %% [raw]
# y_pred = rf_mod2.predict(xts)
# print("Accuracy on test:", accuracy_score(y_test, y_pred))
# print("Precision on test:", precision_score(y_test, y_pred))
# print("Recall on test:", recall_score(y_test, y_pred))
# print("F-1 on test:", f1_score(y_test, y_pred))
# print("AUC on test:", roc_auc_score(y_test, y_pred))

# %% [raw]
# rfb2 = np.sort(rf_mod2.feature_importances_)[::-1]
# rfa2 = np.argsort(rf_mod2.feature_importances_)[::-1]
# var2[rfa2[rfb2>0]]

# %% [markdown]
# # Testing on networked data

# %%
with open(data_dir + 'network.pkl', 'rb') as f:  # Python 3: open(..., 'rb')
        adjacency, edge_weights = pickle.load(f)
